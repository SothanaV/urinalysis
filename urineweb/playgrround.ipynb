# %%
# %matplotlib inline
import json
import pandas as pdf
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from app.models import ExperimentResult

# %%
inst = ExperimentResult.objects.get(pk=36)

# %%
i = json.loads(inst.i)
v = json.loads(inst.v)

# %%
df = pd.DataFrame.from_dict({'i': i, 'v': v})\
        .groupby('v', as_index=False)\
        .count()

# %%
df
# Out:
#        v  i
# 0    259  1
# 1    285  1
# 2    305  1
# 3    306  1
# 4    317  1
# 5    329  1
# 6    330  1
# 7    333  2
# 8    346  1
# 9    350  1
# 10   352  1
# 11   353  1
# 12   356  1
# 13   364  1
# 14   365  1
# 15   366  1
# 16   368  1
# 17   370  2
# 18   374  1
# 19   379  1
# 20   382  1
# 21   391  1
# 22   394  1
# 23   397  1
# 24   400  1
# 25   402  1
# 26   406  1
# 27   408  1
# 28   410  1
# 29   416  1
# ..   ... ..
# 123  666  1
# 124  668  1
# 125  669  1
# 126  671  2
# 127  673  2
# 128  674  1
# 129  675  1
# 130  676  2
# 131  679  1
# 132  680  1
# 133  684  2
# 134  685  2
# 135  686  1
# 136  687  1
# 137  688  5
# 138  689  2
# 139  690  2
# 140  691  1
# 141  692  4
# 142  693  2
# 143  696  1
# 144  697  1
# 145  699  2
# 146  700  1
# 147  703  1
# 148  704  3
# 149  706  1
# 150  708  3
# 151  710  1
# 152  713  1
#
# [153 rows x 2 columns]

# %%
df = pd.DataFrame.from_dict({'i': i, 'v': v})\
#                 .groupby('v', as_index=False)\
#                 .mean()\
#                 .sort_values(by=['v'])

# %%
df.plot.scatter(x='v', y='i')

# %%
df = pd.DataFrame.from_dict({'i': i, 'v': v})\
                .groupby('v', as_index=False)\
                .mean()\
                .sort_values(by=['v'])

# %%
df.plot.scatter(x='v', y='i')

# %%
tdf = df.copy()
tdf.i = tdf.i.interpolate('time')
tdf.plot.scatter(x='v', y='i')

# %%
df
# Out:
#         i    v
# 0    1725  682
# 1    1750  602
# 2    1730  648
# 3    1729  683
# 4    1737  658
# 5    1768  603
# 6    1744  635
# 7    1743  663
# 8    1746  647
# 9    1745  648
# 10   1745  641
# 11   1740  677
# 12   1752  675
# 13   1781  634
# 14   1739  621
# 15   1771  696
# 16   1760  638
# 17   1759  601
# 18   1744  638
# 19   1745  612
# 20   1755  669
# 21   1745  673
# 22   1762  617
# 23   1749  635
# 24   1752  637
# 25   1746  663
# 26   1758  652
# 27   1732  696
# 28   1738  660
# 29   1764  668
# ..    ...  ...
# 210   315  536
# 211   294  549
# 212   206  555
# 213   190  533
# 214   148  538
# 215    87  563
# 216    87  492
# 217    53  499
# 218    37  507
# 219    58  463
# 220     0  461
# 221     8  485
# 222     8  485
# 223     1  440
# 224     0  453
# 225     0  420
# 226     0  418
# 227     0  386
# 228     0  385
# 229     3  363
# 230     0  388
# 231     0  347
# 232     0  371
# 233     0  346
# 234     0  335
# 235     0  317
# ...
