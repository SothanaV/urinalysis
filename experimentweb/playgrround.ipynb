# %%
# %matplotlib inline
import json
import pandas as pd
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from app.models import ExperimentResult

# %%
inst = ExperimentResult.objects.get(pk=109)

# %%
i = json.loads(inst.i)
v = json.loads(inst.v)

# %%
df = pd.DataFrame.from_dict({'i': i, 'v': v})\
        .groupby('v', as_index=False)\
        .count()

# %%
df
# Out:
#         v  i
# 0      38  2
# 1      50  1
# 2      54  1
# 3      56  1
# 4      70  1
# 5      71  2
# 6      72  1
# 7      92  1
# 8     110  1
# 9     111  1
# 10    116  1
# 11    117  1
# 12    121  1
# 13    125  1
# 14    127  2
# 15    131  2
# 16    134  1
# 17    140  2
# 18    144  1
# 19    150  1
# 20    157  1
# 21    161  1
# 22    162  1
# 23    166  1
# 24    168  1
# 25    169  1
# 26    171  1
# 27    173  1
# 28    174  1
# 29    176  1
# ..    ... ..
# 226   940  2
# 227   944  1
# 228   953  2
# 229   955  2
# 230   962  2
# 231   965  1
# 232   969  1
# 233   976  1
# 234   980  1
# 235   982  1
# 236   984  1
# 237   986  1
# 238   988  1
# 239   991  2
# 240   992  1
# 241  1000  1
# 242  1007  1
# 243  1010  1
# 244  1023  2
# 245  1024  1
# 246  1029  1
# 247  1035  1
# 248  1036  1
# 249  1037  1
# 250  1040  1
# 251  1045  1
# 252  1053  1
# 253  1065  1
# 254  1080  1
# 255  1095  1
#
# [256 rows x 2 columns]

# %%
df = pd.DataFrame.from_dict({'i': i, 'v': v})\
#                 .groupby('v', as_index=False)\
#                 .mean()\
#                 .sort_values(by=['v'])

# %%
df.plot.scatter(x='v', y='i')

# %%
df = pd.DataFrame.from_dict({'i': i, 'v': v})\
                .groupby('v', as_index=False)\
                .mean()\
                .sort_values(by=['v'])

# %%
df.plot.scatter(x='v', y='i')

# %%
tdf = df.copy()
tdf.i = tdf.i.interpolate('time')
tdf.plot.scatter(x='v', y='i')

# %%
df
# Out:
#         i    v
# 0    1725  682
# 1    1750  602
# 2    1730  648
# 3    1729  683
# 4    1737  658
# 5    1768  603
# 6    1744  635
# 7    1743  663
# 8    1746  647
# 9    1745  648
# 10   1745  641
# 11   1740  677
# 12   1752  675
# 13   1781  634
# 14   1739  621
# 15   1771  696
# 16   1760  638
# 17   1759  601
# 18   1744  638
# 19   1745  612
# 20   1755  669
# 21   1745  673
# 22   1762  617
# 23   1749  635
# 24   1752  637
# 25   1746  663
# 26   1758  652
# 27   1732  696
# 28   1738  660
# 29   1764  668
# ..    ...  ...
# 210   315  536
# 211   294  549
# 212   206  555
# 213   190  533
# 214   148  538
# 215    87  563
# 216    87  492
# 217    53  499
# 218    37  507
# 219    58  463
# 220     0  461
# 221     8  485
# 222     8  485
# 223     1  440
# 224     0  453
# 225     0  420
# 226     0  418
# 227     0  386
# 228     0  385
# 229     3  363
# 230     0  388
# 231     0  347
# 232     0  371
# 233     0  346
# 234     0  335
# 235     0  317
# 236     0  308
# 237     0  301
# 238     0  334
# 239     0  322
#
# [240 rows x 2 columns]
